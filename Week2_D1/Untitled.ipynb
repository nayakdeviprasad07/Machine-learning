# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

boston = pd.read_csv("boston.csv")

# %%
boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NX         506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %%
boston.CRIM.describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: CRIM, dtype: float64

# %%
plt.hist(boston.CRIM,bins=10,rwidth=1)
plt.xlabel("CRIM")
plt.ylabel("Count")
plt.show()

# %%
boston.ZN.describe()
# Out:
# count    506.000000
# mean      11.363636
# std       23.322453
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       12.500000
# max      100.000000
# Name: ZN, dtype: float64

# %%
plt.hist(boston.ZN,bins=10,rwidth=1)
plt.xlabel("ZN")
plt.ylabel("Count")
plt.show()

# %%
boston.INDUS.describe()
# Out:
# count    506.000000
# mean      11.136779
# std        6.860353
# min        0.460000
# 25%        5.190000
# 50%        9.690000
# 75%       18.100000
# max       27.740000
# Name: INDUS, dtype: float64

# %%
plt.hist(boston.INDUS,bins=10,rwidth=1)
plt.xlabel("INDUS")
plt.ylabel("Count")
plt.show()

# %%
boston["CHAS"].value_counts().plot(kind='bar')
plt.show()

# %%
boston.NX.describe()
# Out:
# count    506.000000
# mean       0.554695
# std        0.115878
# min        0.385000
# 25%        0.449000
# 50%        0.538000
# 75%        0.624000
# max        0.871000
# Name: NX, dtype: float64

# %%
plt.hist(boston.NX,bins=10,rwidth=1)
plt.xlabel("NX")
plt.ylabel("Count")
plt.show()

# %%
boston.RM.describe()
# Out:
# count    506.000000
# mean       6.284634
# std        0.702617
# min        3.561000
# 25%        5.885500
# 50%        6.208500
# 75%        6.623500
# max        8.780000
# Name: RM, dtype: float64

# %%
plt.hist(boston.RM,bins=10,rwidth=1)
plt.xlabel("RM")
plt.ylabel("Count")
plt.show()

# %%
boston.AGE.describe()
# Out:
# count    506.000000
# mean      68.574901
# std       28.148861
# min        2.900000
# 25%       45.025000
# 50%       77.500000
# 75%       94.075000
# max      100.000000
# Name: AGE, dtype: float64

# %%
plt.hist(boston.AGE,bins=10,rwidth=1)
plt.xlabel("AGE")
plt.ylabel("Count")
plt.show()

# %%
boston.DIS.describe()
# Out:
# count    506.000000
# mean       3.795043
# std        2.105710
# min        1.129600
# 25%        2.100175
# 50%        3.207450
# 75%        5.188425
# max       12.126500
# Name: DIS, dtype: float64

# %%
plt.hist(boston.DIS,bins=10,rwidth=1)
plt.xlabel("DIS")
plt.ylabel("Count")
plt.show()

# %%
boston["RAD"].value_counts().plot(kind='bar')
plt.show()

# %%
boston.TAX.describe()
# Out:
# count    506.000000
# mean     408.237154
# std      168.537116
# min      187.000000
# 25%      279.000000
# 50%      330.000000
# 75%      666.000000
# max      711.000000
# Name: TAX, dtype: float64

# %%
plt.hist(boston.TAX,bins=10,rwidth=1)
plt.xlabel("TAX")
plt.ylabel("Count")
plt.show()

# %%
boston.PTRATIO.describe()
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: PTRATIO, dtype: float64

# %%
plt.hist(boston.PTRATIO,bins=10,rwidth=1)
plt.xlabel("PTRATIO")
plt.ylabel("Count")
plt.show()

# %%
boston.B.describe()
# Out:
# count    506.000000
# mean     356.674032
# std       91.294864
# min        0.320000
# 25%      375.377500
# 50%      391.440000
# 75%      396.225000
# max      396.900000
# Name: B, dtype: float64

# %%
plt.hist(boston.B,bins=10,rwidth=1)
plt.xlabel("B")
plt.ylabel("Count")
plt.show()

# %%
boston.LSTAT.describe()
# Out:
# count    506.000000
# mean      12.653063
# std        7.141062
# min        1.730000
# 25%        6.950000
# 50%       11.360000
# 75%       16.955000
# max       37.970000
# Name: LSTAT, dtype: float64

# %%
plt.hist(boston.LSTAT,bins=10,rwidth=1)
plt.xlabel("LSTAT")
plt.ylabel("Count")
plt.show()

# %%
boston.MEDV.describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: MEDV, dtype: float64

# %%
plt.hist(boston.MEDV,bins=10,rwidth=1)
plt.xlabel("MEDV")
plt.ylabel("Count")
plt.show()

# %%
plt.scatter(x=boston.CRIM,y=boston.MEDV)
plt.xlabel("CRIM")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.CRIM,boston.MEDV)
# Out:
# array([[ 1.        , -0.38830461],
#        [-0.38830461,  1.        ]])

# %%
plt.scatter(x=boston.ZN,y=boston.MEDV)
plt.xlabel("ZN")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.ZN,boston.MEDV)
# Out:
# array([[1.        , 0.36044534],
#        [0.36044534, 1.        ]])

# %%
plt.scatter(x=boston.INDUS,y=boston.MEDV)
plt.xlabel("INDUS")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.INDUS,boston.MEDV)
# Out:
# array([[ 1.        , -0.48372516],
#        [-0.48372516,  1.        ]])

# %%
sns.boxplot(x=boston.CHAS,y=boston.MEDV)
plt.show()

# %%
plt.scatter(x=boston.NX,y=boston.MEDV)
plt.xlabel("NX")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.NX,boston.MEDV)
# Out:
# array([[ 1.        , -0.42732077],
#        [-0.42732077,  1.        ]])

# %%
plt.scatter(x=boston.RM,y=boston.MEDV)
plt.xlabel("RM")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.RM,boston.MEDV)
# Out:
# array([[1.        , 0.69535995],
#        [0.69535995, 1.        ]])

# %%
plt.scatter(x=boston.AGE,y=boston.MEDV)
plt.xlabel("AGE")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.AGE,boston.MEDV)
# Out:
# array([[ 1.        , -0.37695457],
#        [-0.37695457,  1.        ]])

# %%
plt.scatter(x=boston.DIS,y=boston.MEDV)
plt.xlabel("DIS")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.DIS,boston.MEDV)
# Out:
# array([[1.        , 0.24992873],
#        [0.24992873, 1.        ]])

# %%
sns.boxplot(x=boston.RAD,y=boston.MEDV)
plt.show()

# %%
plt.scatter(x=boston.TAX,y=boston.MEDV)
plt.xlabel("TAX")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.TAX,boston.MEDV)
# Out:
# array([[ 1.        , -0.46853593],
#        [-0.46853593,  1.        ]])

# %%
plt.scatter(x=boston.PTRATIO,y=boston.MEDV)
plt.xlabel("PTRATIO")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.PTRATIO,boston.MEDV)
# Out:
# array([[ 1.        , -0.50778669],
#        [-0.50778669,  1.        ]])

# %%
plt.scatter(x=boston.B,y=boston.MEDV)
plt.xlabel("B")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.B,boston.MEDV)
# Out:
# array([[1.        , 0.33346082],
#        [0.33346082, 1.        ]])

# %%
plt.scatter(x=boston.LSTAT,y=boston.MEDV)
plt.xlabel("LSTAT")
plt.ylabel("MEDV")
plt.show()

# %%
np.corrcoef(boston.LSTAT,boston.MEDV)
# Out:
# array([[ 1.        , -0.73766273],
#        [-0.73766273,  1.        ]])
