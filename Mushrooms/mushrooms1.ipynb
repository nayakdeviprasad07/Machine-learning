# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
mush=pd.read_csv("mushrooms.csv")

# %%
mush.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# class                       8124 non-null object
# cap-shape                   8124 non-null object
# cap-surface                 8124 non-null object
# cap-color                   8124 non-null object
# bruises                     8124 non-null object
# odor                        8124 non-null object
# gill-attachment             8124 non-null object
# gill-spacing                8124 non-null object
# gill-size                   8124 non-null object
# gill-color                  8124 non-null object
# stalk-shape                 8124 non-null object
# stalk-root                  8124 non-null object
# stalk-surface-above-ring    8124 non-null object
# stalk-surface-below-ring    8124 non-null object
# stalk-color-above-ring      8124 non-null object
# stalk-color-below-ring      8124 non-null object
# veil-type                   8124 non-null object
# ...

# %%
mush["cap-shape"].value_counts().plot(kind='bar')
plt.show()
#Convex mushrooms are more in number (Right skewed)

# %%
mush["cap-surface"].value_counts().plot(kind='bar')
plt.show()
#Scaly capped mushrooms are more in number

# %%
mush["cap-color"].value_counts().plot(kind='bar')
plt.show()
#Brown colored mushrooms are more and purple colored mushrooms are less in number

# %%
mush["bruises"].value_counts().plot(kind='bar')
plt.show()
#More number of mushrooms doesnot have bruises

# %%
mush["odor"].value_counts().plot(kind='bar')
plt.show()
#Most of the mushrooms doesnt have odor

# %%
mush["gill-attachment"].value_counts().plot(kind='bar')
plt.show()
#

# %%
mush["gill-spacing"].value_counts().plot(kind='bar')
plt.show()
#Most of the mushrooms have very close gill spacing

# %%
mush["gill-size"].value_counts().plot(kind='bar')
plt.show()
#Gill size is broad for most of the mushrooms

# %%
mush["gill-color"].value_counts().plot(kind='bar')
plt.show()
#

# %%
mush["stalk-shape"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["stalk-root"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["stalk-surface-above-ring"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["stalk-surface-below-ring"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["stalk-color-above-ring"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["stalk-color-below-ring"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["veil-type"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["veil-color"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["ring-number"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["ring-type"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["spore-print-color"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["population"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["habitat"].value_counts().plot(kind='bar')
plt.show()

# %%
mush["class"].value_counts().plot(kind='bar')
plt.show()

#Edible mushrooms are more than poisonous

# %% [markdown]
# ### Bivariate analysis ###

# %%
pd.crosstab(mush["class"],mush["cap-shape"],margins=True)
# Out:
# cap-shape    b  c     f    k   s     x   All
# class
# e          404  0  1596  228  32  1948  4208
# p           48  4  1556  600   0  1708  3916
# All        452  4  3152  828  32  3656  8124

# %%
pd.crosstab(mush["class"],mush["cap-surface"],margins=True)
# Out:
# cap-surface     f  g     s     y   All
# class
# e            1560  0  1144  1504  4208
# p             760  4  1412  1740  3916
# All          2320  4  2556  3244  8124

# %%
pd.crosstab(mush["class"],mush["cap-color"],margins=True)
# Out:
# cap-color    b   c     e     g     n    p   r   u     w     y   All
# class
# e           48  32   624  1032  1264   56  16  16   720   400  4208
# p          120  12   876   808  1020   88   0   0   320   672  3916
# All        168  44  1500  1840  2284  144  16  16  1040  1072  8124

# %%
pd.crosstab(mush["class"],mush["bruises"],margins=True)
# Out:
# bruises     f     t   All
# class
# e        1456  2752  4208
# p        3292   624  3916
# All      4748  3376  8124

# %%
pd.crosstab(mush["class"],mush["odor"],margins=True)
# Out:
# odor     a    c     f    l   m     n    p    s    y   All
# class
# e      400    0     0  400   0  3408    0    0    0  4208
# p        0  192  2160    0  36   120  256  576  576  3916
# All    400  192  2160  400  36  3528  256  576  576  8124

# %%
pd.crosstab(mush["class"],mush["gill-attachment"],margins=True)
# Out:
# gill-attachment    a     f   All
# class
# e                192  4016  4208
# p                 18  3898  3916
# All              210  7914  8124

# %%
pd.crosstab(mush["class"],mush["gill-spacing"],margins=True)
# Out:
# gill-spacing     c     w   All
# class
# e             3008  1200  4208
# p             3804   112  3916
# All           6812  1312  8124

# %%
pd.crosstab(mush["class"],mush["gill-size"],margins=True)
# Out:
# gill-size     b     n   All
# class
# e          3920   288  4208
# p          1692  2224  3916
# All        5612  2512  8124

# %%
pd.crosstab(mush["class"],mush["gill-color"],margins=True)
# Out:
# gill-color     b   e    g    h    k     n   o     p   r    u     w   y   All
# class
# e              0  96  248  204  344   936  64   852   0  444   956  64  4208
# p           1728   0  504  528   64   112   0   640  24   48   246  22  3916
# All         1728  96  752  732  408  1048  64  1492  24  492  1202  86  8124

# %%
pd.crosstab(mush["class"],mush["stalk-shape"],margins=True)
# Out:
# stalk-shape     e     t   All
# class
# e            1616  2592  4208
# p            1900  2016  3916
# All          3516  4608  8124

# %%
pd.crosstab(mush["class"],mush["stalk-root"],margins=True)
# Out:
# stalk-root     ?     b    c     e    r   All
# class
# e            720  1920  512   864  192  4208
# p           1760  1856   44   256    0  3916
# All         2480  3776  556  1120  192  8124

# %%
pd.crosstab(mush["class"],mush["stalk-surface-above-ring"],margins=True)
# Out:
# stalk-surface-above-ring    f     k     s   y   All
# class
# e                         408   144  3640  16  4208
# p                         144  2228  1536   8  3916
# All                       552  2372  5176  24  8124

# %%
pd.crosstab(mush["class"],mush["stalk-surface-below-ring"],margins=True)
# Out:
# stalk-surface-below-ring    f     k     s    y   All
# class
# e                         456   144  3400  208  4208
# p                         144  2160  1536   76  3916
# All                       600  2304  4936  284  8124

# %%
pd.crosstab(mush["class"],mush["stalk-color-above-ring"],margins=True)
# Out:
# stalk-color-above-ring    b   c   e    g    n    o     p     w  y   All
# class
# e                         0   0  96  576   16  192   576  2752  0  4208
# p                       432  36   0    0  432    0  1296  1712  8  3916
# All                     432  36  96  576  448  192  1872  4464  8  8124

# %%
pd.crosstab(mush["class"],mush["stalk-color-below-ring"],margins=True)
# Out:
# stalk-color-below-ring    b   c   e    g    n    o     p     w   y   All
# class
# e                         0   0  96  576   64  192   576  2704   0  4208
# p                       432  36   0    0  448    0  1296  1680  24  3916
# All                     432  36  96  576  512  192  1872  4384  24  8124

# %%
pd.crosstab(mush["class"],mush["veil-type"],margins=True)
# can be removed
# Out:
# veil-type     p   All
# class
# e          4208  4208
# p          3916  3916
# All        8124  8124

# %%
pd.crosstab(mush["class"],mush["veil-color"],margins=True)
# Out:
# veil-color   n   o     w  y   All
# class
# e           96  96  4016  0  4208
# p            0   0  3908  8  3916
# All         96  96  7924  8  8124

# %%
pd.crosstab(mush["class"],mush["ring-number"],margins=True)
# Out:
# ring-number   n     o    t   All
# class
# e             0  3680  528  4208
# p            36  3808   72  3916
# All          36  7488  600  8124

# %%
pd.crosstab(mush["class"],mush["ring-type"],margins=True)
# Out:
# ring-type     e   f     l   n     p   All
# class
# e          1008  48     0   0  3152  4208
# p          1768   0  1296  36   816  3916
# All        2776  48  1296  36  3968  8124

# %%
pd.crosstab(mush["class"],mush["spore-print-color"],margins=True)
# Out:
# spore-print-color   b     h     k     n   o   r   u     w   y   All
# class
# e                  48    48  1648  1744  48   0  48   576  48  4208
# p                   0  1584   224   224   0  72   0  1812   0  3916
# All                48  1632  1872  1968  48  72  48  2388  48  8124

# %%
pd.crosstab(mush["class"],mush["population"],margins=True)
# Out:
# population    a    c    n     s     v     y   All
# class
# e           384  288  400   880  1192  1064  4208
# p             0   52    0   368  2848   648  3916
# All         384  340  400  1248  4040  1712  8124

# %%
pd.crosstab(mush["class"],mush["habitat"],margins=True)
# Out:
# habitat     d     g    l    m     p    u    w   All
# class
# e        1880  1408  240  256   136   96  192  4208
# p        1268   740  592   36  1008  272    0  3916
# All      3148  2148  832  292  1144  368  192  8124

# %%
cat_col = mush.select_dtypes(include=['object']).columns
dummies = pd.get_dummies(mush[cat_col],drop_first=True)
without_dummies = mush.drop(cat_col,axis=1)

# %%
data = pd.concat([dummies,without_dummies],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 96 columns):
# class_p                       8124 non-null uint8
# cap-shape_c                   8124 non-null uint8
# cap-shape_f                   8124 non-null uint8
# cap-shape_k                   8124 non-null uint8
# cap-shape_s                   8124 non-null uint8
# cap-shape_x                   8124 non-null uint8
# cap-surface_g                 8124 non-null uint8
# cap-surface_s                 8124 non-null uint8
# cap-surface_y                 8124 non-null uint8
# cap-color_c                   8124 non-null uint8
# cap-color_e                   8124 non-null uint8
# cap-color_g                   8124 non-null uint8
# cap-color_n                   8124 non-null uint8
# cap-color_p                   8124 non-null uint8
# cap-color_r                   8124 non-null uint8
# cap-color_u                   8124 non-null uint8
# cap-color_w                   8124 non-null uint8
# ...

# %%
y = data["class_p"]
x = data.drop(["class_p"],axis=1)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                    test_size=0.3,random_state=1)
logreg = LogisticRegression()
logreg.fit(x_train,y_train)
ypred  = logreg.predict(x_test)
from sklearn import metrics
print(metrics.log_loss(y_test,ypred))
print(metrics.accuracy_score(y_test,ypred))
# Out:
# 0.0708342419912042
# 0.9979491386382281
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
y = data["class_p"]
x = data.drop(["class_p"],axis=1)
from sklearn import metrics
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                    test_size=0.3,random_state=1)
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=75)
knn_model.fit(x_train,y_train)
ypred_knn=knn_model.predict(x_test)
print(metrics.accuracy_score(y_test,ypred_knn))
# Out:
# 0.9971287940935193

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(max_depth=15)
dt.fit(x_train,y_train)
ypred_dt=dt.predict(x_test)
print(metrics.accuracy_score(y_test,ypred_dt))
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=50)
forest.fit(x_train,y_train)
ypred_forest=forest.predict(x_test)
print(metrics.accuracy_score(y_test,ypred_forest))
# Out:
# 1.0
